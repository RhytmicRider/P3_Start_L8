# %% [markdown]
# # Gezichtsherkenning

# %%
# %pip install ultralytics supervision

# %%
url = "https://codefeverpublic.blob.core.windows.net/public-content/images/095ce574c6fe4a718d59b7c1717a051c.png"
